# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("./raw_data/selected/부산교통공사_도시철도 역별 수송 수입현황.csv",encoding="EUC-KR")

# %%
from matplotlib import font_manager, rc
path="/usr/share/fonts/Pretendard-Medium.ttf"
font_name=font_manager.FontProperties(fname=path).get_name()

rc("font",family=font_name)
print(font_name)

fontprop=font_manager.FontProperties(fname=path,size=12)
# Out:
# Pretendard

# %%
# "역명"을 X축으로, 나머지 column을 Y축으로 설정하여 막대 그래프 그리기
plt.figure(figsize=(10, 6))
# plt.bar(df["역명"], df["하차(명)"]*df["승차(명)"], label="승하차(명^2)", color="b", alpha=0.7)
plt.bar(df["역명"], df["일평균(원)"], label="일평균", color="b", alpha=0.7)
# plt.bar(df["역명"], , label="하차(명)", color="r", alpha=0.7)
plt.xlabel("역명")
plt.ylabel("승차/하차 인원")
plt.title("지하철 역별 승차/하차 인원")
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# findfont: Font family 'Pretendard' not found.
# findfont: Font family 'Pretendard' not found.
# /tmp/ipykernel_3620/2622112316.py:11: UserWarning: Glyph 45796 (\N{HANGUL SYLLABLE DA}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_3620/2622112316.py:11: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_3620/2622112316.py:11: UserWarning: Glyph 54252 (\N{HANGUL SYLLABLE PO}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_3620/2622112316.py:11: UserWarning: Glyph 54644 (\N{HANGUL SYLLABLE HAE}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_3620/2622112316.py:11: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_3620/2622112316.py:11: UserWarning: Glyph 50837 (\N{HANGUL SYLLABLE YOG}) missing from current font.
#   plt.tight_layout()
# ...
